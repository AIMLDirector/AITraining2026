# %%
pip install pyspark
# Out:
# ...
#   Using cached pyspark-4.0.1-py2.py3-none-any.whl
# ...
#   Obtaining dependency information for py4j==0.10.9.9 from https://files.pythonhosted.org/packages/bd/db/ea0203e495be491c85af87b66e37acfd3bf756fd985f87e46fc5e3bf022c/py4j-0.10.9.9-py2.py3-none-any.whl.metadata
#   Using cached py4j-0.10.9.9-py2.py3-none-any.whl.metadata (1.3 kB)
# Using cached py4j-0.10.9.9-py2.py3-none-any.whl (203 kB)
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyspark

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("ReadCSVExample").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/12/14 07:27:28 WARN Utils: Your hostname, Premkumars-MacBook-Pro.local, resolves to a loopback address: 127.0.0.1; using 192.168.0.108 instead (on interface en0)
# 25/12/14 07:27:28 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/14 07:27:31 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
csv_file_path = "NLPTraining/Data-Analysis-with-Pandas-and-Python/bigmac.csv"

# %%
df = spark.read.csv(csv_file_path, header=True, inferSchema=True)

# %%
df.show()
# Out:
# +------+--------------+-------------------+
# |  Date|       Country|Price in US Dollars|
# +------+--------------+-------------------+
# |1/2016|     Argentina|               2.39|
# |1/2016|     Australia|               3.74|
# |1/2016|        Brazil|               3.35|
# |1/2016|       Britain|               4.22|
# |1/2016|        Canada|               4.14|
# |1/2016|         Chile|               2.94|
# |1/2016|         China|               2.68|
# |1/2016|      Colombia|               2.43|
# |1/2016|    Costa Rica|               4.02|
# |1/2016|Czech Republic|               2.98|
# |1/2016|       Denmark|               4.32|
# |1/2016|         Egypt|               2.16|
# |1/2016|     Euro area|                4.0|
# |1/2016|     Hong Kong|               2.48|
# |1/2016|       Hungary|               3.08|
# |1/2016|         India|                1.9|
# |1/2016|     Indonesia|               2.19|
# |1/2016|        Israel|               4.29|
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# PySparkAttributeError                     Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.info
#
# File ~/AITraining/AIvenv/lib/python3.11/site-packages/pyspark/sql/classic/dataframe.py:971, in DataFrame.__getattr__(self, name)
#     969 def __getattr__(self, name: str) -> Column:
#     970     if name not in self.columns:
# --> 971         raise PySparkAttributeError(
#     972             errorClass="ATTRIBUTE_NOT_SUPPORTED", messageParameters={"attr_name": name}
#     973         )
#     974     jc = self._jdf.apply(name)
#     975     return Column(jc)
#
# PySparkAttributeError: [ATTRIBUTE_NOT_SUPPORTED] Attribute `info` is not supported.
